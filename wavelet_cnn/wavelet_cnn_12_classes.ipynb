# %%
import numpy as np
from matplotlib import pyplot as plt
import re
import os
import random
import pandas as pd
import tensorflow as tf
import keras
import glob
import cv2
import numpy as np
from random import shuffle
from tqdm import tqdm
from tensorflow.python.framework import graph_util
from keras.layers import *
from keras.optimizers import *
import sys
import pandas as pd
import pickle
import time
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import Adam
from skimage.io import imshow
from keras.layers.normalization import BatchNormalization
from keras.initializers import glorot_uniform
from keras.engine.topology import Layer
from sklearn.utils import shuffle
import numpy.random as rng
from keras.utils import to_categorical
from keras.utils import np_utils
from keras.utils import to_categorical
from keras.models import Model, load_model
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from sklearn.model_selection import train_test_split
from functools import partial, update_wrapper
import pydot
#install pip pydot_ng
from keras import backend as K
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import Lambda
from keras.layers import Flatten
from keras.layers import Reshape
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import AveragePooling2D
from keras.layers import BatchNormalization
from keras.layers.merge import add, concatenate
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model
import pydot
#install pip pydot_ng
import pydot_ng as pydot
print (pydot.find_graphviz())
np.random.seed(42)
# %matplotlib inline
plt.rcParams['image.cmap'] = 'gray'
# Out:
# Using TensorFlow backend.
# {'dot': 'C:\\Program Files\\Graphviz 2.44.1\\bin\\dot.exe', 'twopi': '', 'neato': '', 'circo': '', 'fdp': '', 'sfdp': ''}

# %%
#print("tf.version is", tf.version)
#print("tf.keras.version is:", tf.keras.version)

def _get_available_gpus():
    """Get a list of available gpu devices (formatted as strings).

    # Returns
        A list of available GPU devices.
    """
    #global _LOCAL_DEVICES
    if tfback._LOCAL_DEVICES is None:
        devices = tf.config.list_logical_devices()
        tfback._LOCAL_DEVICES = [x.name for x in devices]
    return [x for x in tfback._LOCAL_DEVICES if 'device:gpu' in x.lower()]

#tfback._get_available_gpus = _get_available_gpus
#tfback._get_available_gpus()
#tf.config.list_logical_devices()

# %%
# batch operation usng tensor slice
def WaveletTransformAxisY(batch_img):
    odd_img  = batch_img[:,0::2]
    even_img = batch_img[:,1::2]
    L = (odd_img + even_img) / 2.0
    H = K.abs(odd_img - even_img)
    return L, H

def WaveletTransformAxisX(batch_img):
    # transpose + fliplr
    tmp_batch = K.permute_dimensions(batch_img, [0, 2, 1])[:,:,::-1]
    _dst_L, _dst_H = WaveletTransformAxisY(tmp_batch)
    # transpose + flipud
    dst_L = K.permute_dimensions(_dst_L, [0, 2, 1])[:,::-1,...]
    dst_H = K.permute_dimensions(_dst_H, [0, 2, 1])[:,::-1,...]
    return dst_L, dst_H

# %%
def Wavelet(batch_image):
    # make channel first image
    batch_image = K.permute_dimensions(batch_image, [0, 3, 1, 2])
    r = batch_image[:,0]
    g = batch_image[:,1]
    b = batch_image[:,2]

    # level 1 decomposition
    wavelet_L, wavelet_H = WaveletTransformAxisY(r)
    r_wavelet_LL, r_wavelet_LH = WaveletTransformAxisX(wavelet_L)
    r_wavelet_HL, r_wavelet_HH = WaveletTransformAxisX(wavelet_H)

    wavelet_L, wavelet_H = WaveletTransformAxisY(g)
    g_wavelet_LL, g_wavelet_LH = WaveletTransformAxisX(wavelet_L)
    g_wavelet_HL, g_wavelet_HH = WaveletTransformAxisX(wavelet_H)

    wavelet_L, wavelet_H = WaveletTransformAxisY(b)
    b_wavelet_LL, b_wavelet_LH = WaveletTransformAxisX(wavelet_L)
    b_wavelet_HL, b_wavelet_HH = WaveletTransformAxisX(wavelet_H)

    wavelet_data = [r_wavelet_LL, r_wavelet_LH, r_wavelet_HL, r_wavelet_HH, 
                    g_wavelet_LL, g_wavelet_LH, g_wavelet_HL, g_wavelet_HH,
                    b_wavelet_LL, b_wavelet_LH, b_wavelet_HL, b_wavelet_HH]
    transform_batch = K.stack(wavelet_data, axis=1)

    # level 2 decomposition
    wavelet_L2, wavelet_H2 = WaveletTransformAxisY(r_wavelet_LL)
    r_wavelet_LL2, r_wavelet_LH2 = WaveletTransformAxisX(wavelet_L2)
    r_wavelet_HL2, r_wavelet_HH2 = WaveletTransformAxisX(wavelet_H2)

    wavelet_L2, wavelet_H2 = WaveletTransformAxisY(g_wavelet_LL)
    g_wavelet_LL2, g_wavelet_LH2 = WaveletTransformAxisX(wavelet_L2)
    g_wavelet_HL2, g_wavelet_HH2 = WaveletTransformAxisX(wavelet_H2)

    wavelet_L2, wavelet_H2 = WaveletTransformAxisY(b_wavelet_LL)
    b_wavelet_LL2, b_wavelet_LH2 = WaveletTransformAxisX(wavelet_L2)
    b_wavelet_HL2, b_wavelet_HH2 = WaveletTransformAxisX(wavelet_H2)


    wavelet_data_l2 = [r_wavelet_LL2, r_wavelet_LH2, r_wavelet_HL2, r_wavelet_HH2, 
                    g_wavelet_LL2, g_wavelet_LH2, g_wavelet_HL2, g_wavelet_HH2,
                    b_wavelet_LL2, b_wavelet_LH2, b_wavelet_HL2, b_wavelet_HH2]
    transform_batch_l2 = K.stack(wavelet_data_l2, axis=1)

    # level 3 decomposition
    wavelet_L3, wavelet_H3 = WaveletTransformAxisY(r_wavelet_LL2)
    r_wavelet_LL3, r_wavelet_LH3 = WaveletTransformAxisX(wavelet_L3)
    r_wavelet_HL3, r_wavelet_HH3 = WaveletTransformAxisX(wavelet_H3)

    wavelet_L3, wavelet_H3 = WaveletTransformAxisY(g_wavelet_LL2)
    g_wavelet_LL3, g_wavelet_LH3 = WaveletTransformAxisX(wavelet_L3)
    g_wavelet_HL3, g_wavelet_HH3 = WaveletTransformAxisX(wavelet_H3)

    wavelet_L3, wavelet_H3 = WaveletTransformAxisY(b_wavelet_LL2)
    b_wavelet_LL3, b_wavelet_LH3 = WaveletTransformAxisX(wavelet_L3)
    b_wavelet_HL3, b_wavelet_HH3 = WaveletTransformAxisX(wavelet_H3)

    wavelet_data_l3 = [r_wavelet_LL3, r_wavelet_LH3, r_wavelet_HL3, r_wavelet_HH3, 
                    g_wavelet_LL3, g_wavelet_LH3, g_wavelet_HL3, g_wavelet_HH3,
                    b_wavelet_LL3, b_wavelet_LH3, b_wavelet_HL3, b_wavelet_HH3]
    transform_batch_l3 = K.stack(wavelet_data_l3, axis=1)

    # level 4 decomposition
    wavelet_L4, wavelet_H4 = WaveletTransformAxisY(r_wavelet_LL3)
    r_wavelet_LL4, r_wavelet_LH4 = WaveletTransformAxisX(wavelet_L4)
    r_wavelet_HL4, r_wavelet_HH4 = WaveletTransformAxisX(wavelet_H4)

    wavelet_L4, wavelet_H4 = WaveletTransformAxisY(g_wavelet_LL3)
    g_wavelet_LL4, g_wavelet_LH4 = WaveletTransformAxisX(wavelet_L4)
    g_wavelet_HL4, g_wavelet_HH4 = WaveletTransformAxisX(wavelet_H4)

    wavelet_L3, wavelet_H3 = WaveletTransformAxisY(b_wavelet_LL3)
    b_wavelet_LL4, b_wavelet_LH4 = WaveletTransformAxisX(wavelet_L4)
    b_wavelet_HL4, b_wavelet_HH4 = WaveletTransformAxisX(wavelet_H4)


    wavelet_data_l4 = [r_wavelet_LL4, r_wavelet_LH4, r_wavelet_HL4, r_wavelet_HH4, 
                    g_wavelet_LL4, g_wavelet_LH4, g_wavelet_HL4, g_wavelet_HH4,
                    b_wavelet_LL4, b_wavelet_LH4, b_wavelet_HL4, b_wavelet_HH4]
    transform_batch_l4 = K.stack(wavelet_data_l4, axis=1)

    # print('shape before')
    # print(transform_batch.shape)
    # print(transform_batch_l2.shape)
    # print(transform_batch_l3.shape)
    # print(transform_batch_l4.shape)

    decom_level_1 = K.permute_dimensions(transform_batch, [0, 2, 3, 1])
    decom_level_2 = K.permute_dimensions(transform_batch_l2, [0, 2, 3, 1])
    decom_level_3 = K.permute_dimensions(transform_batch_l3, [0, 2, 3, 1])
    decom_level_4 = K.permute_dimensions(transform_batch_l4, [0, 2, 3, 1])
    
    # print('shape after')
    # print(decom_level_1.shape)
    # print(decom_level_2.shape)
    # print(decom_level_3.shape)
    # print(decom_level_4.shape)
    return [decom_level_1, decom_level_2, decom_level_3, decom_level_4]


def Wavelet_out_shape(input_shapes):
    # print('in to shape')
    return [tuple([None, 112, 112, 12]), tuple([None, 56, 56, 12]), 
            tuple([None, 28, 28, 12]), tuple([None, 14, 14, 12])]

# %%
img_batch = K.zeros(shape=(8, 224, 224, 3), dtype='float32')
Wavelet(img_batch)
# Out:
# [<tf.Tensor 'transpose_73:0' shape=(8, 112, 112, 12) dtype=float32>,
#  <tf.Tensor 'transpose_74:0' shape=(8, 56, 56, 12) dtype=float32>,
#  <tf.Tensor 'transpose_75:0' shape=(8, 28, 28, 12) dtype=float32>,
#  <tf.Tensor 'transpose_76:0' shape=(8, 14, 14, 12) dtype=float32>]

# %%
def get_wavelet_cnn_model():

    input_shape = 224, 224, 3

    input_ = Input(input_shape, name='the_input')
    # wavelet = Lambda(Wavelet, name='wavelet')
    wavelet = Lambda(Wavelet, Wavelet_out_shape, name='wavelet')
    input_l1, input_l2, input_l3, input_l4 = wavelet(input_)
    # print(input_l1)
    # print(input_l2)
    # print(input_l3)
    # print(input_l4)
    # level one decomposition starts
    conv_1 = Conv2D(64, kernel_size=(3, 3), padding='same', name='conv_1')(input_l1)
    norm_1 = BatchNormalization(name='norm_1')(conv_1)
    relu_1 = Activation('relu', name='relu_1')(norm_1)

    conv_1_2 = Conv2D(64, kernel_size=(3, 3), strides=(2, 2), padding='same', name='conv_1_2')(relu_1)
    norm_1_2 = BatchNormalization(name='norm_1_2')(conv_1_2)
    relu_1_2 = Activation('relu', name='relu_1_2')(norm_1_2)

    # level two decomposition starts
    conv_a = Conv2D(filters=64, kernel_size=(3, 3), padding='same', name='conv_a')(input_l2)
    norm_a = BatchNormalization(name='norm_a')(conv_a)
    relu_a = Activation('relu', name='relu_a')(norm_a)

    # concate level one and level two decomposition
    concate_level_2 = concatenate([relu_1_2, relu_a])
    conv_2 = Conv2D(128, kernel_size=(3, 3), padding='same', name='conv_2')(concate_level_2)
    norm_2 = BatchNormalization(name='norm_2')(conv_2)
    relu_2 = Activation('relu', name='relu_2')(norm_2)

    conv_2_2 = Conv2D(128, kernel_size=(3, 3), strides=(2, 2), padding='same', name='conv_2_2')(relu_2)
    norm_2_2 = BatchNormalization(name='norm_2_2')(conv_2_2)
    relu_2_2 = Activation('relu', name='relu_2_2')(norm_2_2)

    # level three decomposition starts 
    conv_b = Conv2D(filters=64, kernel_size=(3, 3), padding='same', name='conv_b')(input_l3)
    norm_b = BatchNormalization(name='norm_b')(conv_b)
    relu_b = Activation('relu', name='relu_b')(norm_b)

    conv_b_2 = Conv2D(128, kernel_size=(3, 3), padding='same', name='conv_b_2')(relu_b)
    norm_b_2 = BatchNormalization(name='norm_b_2')(conv_b_2)
    relu_b_2 = Activation('relu', name='relu_b_2')(norm_b_2)

    # concate level two and level three decomposition 
    concate_level_3 = concatenate([relu_2_2, relu_b_2])
    conv_3 = Conv2D(256, kernel_size=(3, 3), padding='same', name='conv_3')(concate_level_3)
    norm_3 = BatchNormalization(name='nomr_3')(conv_3)
    relu_3 = Activation('relu', name='relu_3')(norm_3)

    conv_3_2 = Conv2D(256, kernel_size=(3, 3), strides=(2, 2), padding='same', name='conv_3_2')(relu_3)
    norm_3_2 = BatchNormalization(name='norm_3_2')(conv_3_2)
    relu_3_2 = Activation('relu', name='relu_3_2')(norm_3_2)

    # level four decomposition start
    conv_c = Conv2D(64, kernel_size=(3, 3), padding='same', name='conv_c')(input_l4)
    norm_c = BatchNormalization(name='norm_c')(conv_c)
    relu_c = Activation('relu', name='relu_c')(norm_c)

    conv_c_2 = Conv2D(256, kernel_size=(3, 3), padding='same', name='conv_c_2')(relu_c)
    norm_c_2 = BatchNormalization(name='norm_c_2')(conv_c_2)
    relu_c_2 = Activation('relu', name='relu_c_2')(norm_c_2)

    conv_c_3 = Conv2D(256, kernel_size=(3, 3), padding='same', name='conv_c_3')(relu_c_2)
    norm_c_3 = BatchNormalization(name='norm_c_3')(conv_c_3)
    relu_c_3 = Activation('relu', name='relu_c_3')(norm_c_3)

    # concate level level three and level four decomposition
    concate_level_4 = concatenate([relu_3_2, relu_c_3])
    conv_4 = Conv2D(256, kernel_size=(3, 3), padding='same', name='conv_4')(concate_level_4)
    norm_4 = BatchNormalization(name='norm_4')(conv_4)
    relu_4 = Activation('relu', name='relu_4')(norm_4)

    conv_4_2 = Conv2D(256, kernel_size=(3, 3), strides=(2, 2), padding='same', name='conv_4_2')(relu_4)
    norm_4_2 = BatchNormalization(name='norm_4_2')(conv_4_2)
    relu_4_2 = Activation('relu', name='relu_4_2')(norm_4_2)

    conv_5_1 = Conv2D(128, kernel_size=(3, 3), padding='same', name='conv_5_1')(relu_4_2)
    norm_5_1 = BatchNormalization(name='norm_5_1')(conv_5_1)
    relu_5_1 = Activation('relu', name='relu_5_1')(norm_5_1)

    pool_5_1 = AveragePooling2D(pool_size=(7, 7), strides=1, padding='same', name='avg_pool_5_1')(relu_5_1)
    flat_5_1 = Flatten(name='flat_5_1')(pool_5_1) 

    fc_5 = Dense(1024, name='fc_5')(flat_5_1)
    norm_5 = BatchNormalization(name='norm_5')(fc_5)
    relu_5 = Activation('relu', name='relu_5')(norm_5)
    drop_5 = Dropout(0.5, name='drop_5')(relu_5)

    #fc_6 = Dense(2048, name='fc_6')(drop_5)
    #norm_6 = BatchNormalization(name='norm_6')(fc_6)
    #relu_6 = Activation('relu', name='relu_6')(norm_6)
    #drop_6 = Dropout(0.5, name='drop_6')(relu_6)

    output = Dense(12, activation='softmax', name='fc_7')(drop_5)

    model = Model(inputs=input_, outputs=output)
    model.summary()
    plot_model(model, to_file='neurowavel_classification.png')
    #plot_model(model, show_shapes=True, show_layer_names=True)

    return model

# %%
model = get_wavelet_cnn_model()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_input (InputLayer)          (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# wavelet (Lambda)                [(None, 112, 112, 12 0           the_input[0][0]
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 112, 112, 64) 6976        wavelet[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 112, 112, 64) 256         conv_1[0][0]
# __________________________________________________________________________________________________
# relu_1 (Activation)             (None, 112, 112, 64) 0           norm_1[0][0]
# __________________________________________________________________________________________________
# conv_1_2 (Conv2D)               (None, 56, 56, 64)   36928       relu_1[0][0]
# __________________________________________________________________________________________________
# conv_a (Conv2D)                 (None, 56, 56, 64)   6976        wavelet[0][1]
# __________________________________________________________________________________________________
# norm_1_2 (BatchNormalization)   (None, 56, 56, 64)   256         conv_1_2[0][0]
# __________________________________________________________________________________________________
# norm_a (BatchNormalization)     (None, 56, 56, 64)   256         conv_a[0][0]
# __________________________________________________________________________________________________
# relu_1_2 (Activation)           (None, 56, 56, 64)   0           norm_1_2[0][0]
# __________________________________________________________________________________________________
# relu_a (Activation)             (None, 56, 56, 64)   0           norm_a[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56, 56, 128)  0           relu_1_2[0][0]
#                                                                  relu_a[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 56, 56, 128)  147584      concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_b (Conv2D)                 (None, 28, 28, 64)   6976        wavelet[0][2]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 56, 56, 128)  512         conv_2[0][0]
# __________________________________________________________________________________________________
# norm_b (BatchNormalization)     (None, 28, 28, 64)   256         conv_b[0][0]
# __________________________________________________________________________________________________
# relu_2 (Activation)             (None, 56, 56, 128)  0           norm_2[0][0]
# __________________________________________________________________________________________________
# relu_b (Activation)             (None, 28, 28, 64)   0           norm_b[0][0]
# __________________________________________________________________________________________________
# conv_2_2 (Conv2D)               (None, 28, 28, 128)  147584      relu_2[0][0]
# __________________________________________________________________________________________________
# conv_b_2 (Conv2D)               (None, 28, 28, 128)  73856       relu_b[0][0]
# __________________________________________________________________________________________________
# norm_2_2 (BatchNormalization)   (None, 28, 28, 128)  512         conv_2_2[0][0]
# __________________________________________________________________________________________________
# norm_b_2 (BatchNormalization)   (None, 28, 28, 128)  512         conv_b_2[0][0]
# __________________________________________________________________________________________________
# conv_c (Conv2D)                 (None, 14, 14, 64)   6976        wavelet[0][3]
# __________________________________________________________________________________________________
# relu_2_2 (Activation)           (None, 28, 28, 128)  0           norm_2_2[0][0]
# __________________________________________________________________________________________________
# relu_b_2 (Activation)           (None, 28, 28, 128)  0           norm_b_2[0][0]
# __________________________________________________________________________________________________
# norm_c (BatchNormalization)     (None, 14, 14, 64)   256         conv_c[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 28, 28, 256)  0           relu_2_2[0][0]
#                                                                  relu_b_2[0][0]
# __________________________________________________________________________________________________
# relu_c (Activation)             (None, 14, 14, 64)   0           norm_c[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 28, 28, 256)  590080      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_c_2 (Conv2D)               (None, 14, 14, 256)  147712      relu_c[0][0]
# __________________________________________________________________________________________________
# nomr_3 (BatchNormalization)     (None, 28, 28, 256)  1024        conv_3[0][0]
# __________________________________________________________________________________________________
# norm_c_2 (BatchNormalization)   (None, 14, 14, 256)  1024        conv_c_2[0][0]
# __________________________________________________________________________________________________
# relu_3 (Activation)             (None, 28, 28, 256)  0           nomr_3[0][0]
# __________________________________________________________________________________________________
# relu_c_2 (Activation)           (None, 14, 14, 256)  0           norm_c_2[0][0]
# __________________________________________________________________________________________________
# conv_3_2 (Conv2D)               (None, 14, 14, 256)  590080      relu_3[0][0]
# __________________________________________________________________________________________________
# conv_c_3 (Conv2D)               (None, 14, 14, 256)  590080      relu_c_2[0][0]
# __________________________________________________________________________________________________
# norm_3_2 (BatchNormalization)   (None, 14, 14, 256)  1024        conv_3_2[0][0]
# __________________________________________________________________________________________________
# norm_c_3 (BatchNormalization)   (None, 14, 14, 256)  1024        conv_c_3[0][0]
# __________________________________________________________________________________________________
# relu_3_2 (Activation)           (None, 14, 14, 256)  0           norm_3_2[0][0]
# __________________________________________________________________________________________________
# relu_c_3 (Activation)           (None, 14, 14, 256)  0           norm_c_3[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 14, 14, 512)  0           relu_3_2[0][0]
#                                                                  relu_c_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 14, 14, 256)  1179904     concatenate_6[0][0]
# __________________________________________________________________________________________________
# norm_4 (BatchNormalization)     (None, 14, 14, 256)  1024        conv_4[0][0]
# __________________________________________________________________________________________________
# relu_4 (Activation)             (None, 14, 14, 256)  0           norm_4[0][0]
# __________________________________________________________________________________________________
# conv_4_2 (Conv2D)               (None, 7, 7, 256)    590080      relu_4[0][0]
# __________________________________________________________________________________________________
# norm_4_2 (BatchNormalization)   (None, 7, 7, 256)    1024        conv_4_2[0][0]
# __________________________________________________________________________________________________
# relu_4_2 (Activation)           (None, 7, 7, 256)    0           norm_4_2[0][0]
# __________________________________________________________________________________________________
# conv_5_1 (Conv2D)               (None, 7, 7, 128)    295040      relu_4_2[0][0]
# __________________________________________________________________________________________________
# norm_5_1 (BatchNormalization)   (None, 7, 7, 128)    512         conv_5_1[0][0]
# __________________________________________________________________________________________________
# relu_5_1 (Activation)           (None, 7, 7, 128)    0           norm_5_1[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_1 (AveragePooling2D) (None, 7, 7, 128)    0           relu_5_1[0][0]
# __________________________________________________________________________________________________
# flat_5_1 (Flatten)              (None, 6272)         0           avg_pool_5_1[0][0]
# __________________________________________________________________________________________________
# fc_5 (Dense)                    (None, 1024)         6423552     flat_5_1[0][0]
# __________________________________________________________________________________________________
# norm_5 (BatchNormalization)     (None, 1024)         4096        fc_5[0][0]
# __________________________________________________________________________________________________
# relu_5 (Activation)             (None, 1024)         0           norm_5[0][0]
# __________________________________________________________________________________________________
# drop_5 (Dropout)                (None, 1024)         0           relu_5[0][0]
# __________________________________________________________________________________________________
# fc_7 (Dense)                    (None, 12)           12300       drop_5[0][0]
# ==================================================================================================
# Total params: 10,866,252
# Trainable params: 10,859,468
# Non-trainable params: 6,784
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import os
data_set_path = 'D:/HAPPY WAVELET/Paper 1 Version 2 Classification with Training _Validation Directory/12 Classes/dataset'
os.listdir(data_set_path)

#D:\NEURAL-WAVELET CODES\Task 1\dataset\training_data
#D:\NEURAL-WAVELET CODES\Task 1\dataset\validation_data
# Out:
# ['Training', 'Validation']

# %%
# prepare data augmentation configuration
#Data Division
nb_train_samples = 1620
nb_validation_samples =324
batch_size=32


train_data_gen = ImageDataGenerator(
    #rescale=1./255,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)
val_data_gen = ImageDataGenerator(
    #rescale=1./255
)

train_img_dir = 'D:/HAPPY WAVELET/Paper 1 Version 2 Classification with Training _Validation Directory/12 Classes/dataset/Training'
val_img_dir   = 'D:/HAPPY WAVELET/Paper 1 Version 2 Classification with Training _Validation Directory/12 Classes/dataset/Validation'

# def train & test generators
train_generator = train_data_gen.flow_from_directory(
    train_img_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical')
val_generator = val_data_gen.flow_from_directory(
    val_img_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 1620 images belonging to 12 classes.
# Found 324 images belonging to 12 classes.

# %%
METRICS = [
        tf.keras.metrics.CategoricalAccuracy(),
        tf.keras.metrics.TopKCategoricalAccuracy(k=5, name="top_k_categorical_accuracy"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
        tf.keras.metrics.AUC(name="AUC"),
        tf.keras.metrics.TruePositives(name="true_positives"),
        tf.keras.metrics.TrueNegatives(name="true_negatives"),
        tf.keras.metrics.FalsePositives(name="false_positives"),
        tf.keras.metrics.FalseNegatives(name="false_negatives"),
        keras.metrics.SensitivityAtSpecificity(0.5, name = "sensitivity"),
        keras.metrics.SpecificityAtSensitivity(0.5, name = "specificity")]
    
#model.compile(optimizer=keras.optimizers.Adam(0.0004), loss="categoricaly_crossentropy", metrics=METRICS)
model.compile(optimizer=keras.optimizers.Adam(0.0001), loss=keras.losses.CategoricalCrossentropy(), metrics=METRICS)
# Out:
# WARNING:tensorflow:From C:\Users\PC\Anaconda3\envs\grace\lib\site-packages\keras\backend\tensorflow_backend.py:3172: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
history = model.fit_generator(
    train_generator,
    #steps_per_epoch=1620//16,
    epochs=20,
    validation_data=val_generator,
    #validation_steps=324,
    verbose=1
)

model.save('neurowavel_class_12.h5')
# Out:
# WARNING:tensorflow:From C:\Users\PC\Anaconda3\envs\grace\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/20
# 51/51 [==============================] - 18s 356ms/step - loss: 2.1349 - categorical_accuracy: 0.2751 - top_k_categorical_accuracy: 0.7151 - precision: 0.3772 - recall: 0.1445 - AUC: 0.7203 - true_positives: 138.9412 - true_negatives: 8916.9805 - false_positives: 196.1961 - false_negatives: 689.5294 - sensitivity: 0.8988 - specificity: 0.8729 - val_loss: 3.3130 - val_categorical_accuracy: 0.3054 - val_top_k_categorical_accuracy: 0.7583 - val_precision: 0.4534 - val_recall: 0.1807 - val_AUC: 0.7750 - val_true_positives: 326.0000 - val_true_negatives: 19511.0000 - val_false_positives: 393.0000 - val_false_negatives: 1483.4546 - val_sensitivity: 0.5000 - val_specificity: 0.5123
# Epoch 2/20
# 51/51 [==============================] - 16s 318ms/step - loss: 1.6848 - categorical_accuracy: 0.3274 - top_k_categorical_accuracy: 0.7725 - precision: 0.4960 - recall: 0.2034 - AUC: 0.7928 - true_positives: 570.7059 - true_negatives: 29900.2148 - false_positives: 571.0784 - false_negatives: 2199.4119 - sensitivity: 0.9611 - specificity: 0.9332 - val_loss: 2.1009 - val_categorical_accuracy: 0.3483 - val_top_k_categorical_accuracy: 0.7887 - val_precision: 0.5250 - val_recall: 0.2159 - val_AUC: 0.8074 - val_true_positives: 810.0000 - val_true_negatives: 40555.0000 - val_false_positives: 733.0000 - val_false_negatives: 2943.4546 - val_sensitivity: 0.7469 - val_specificity: 0.7245
# Epoch 3/20
# 51/51 [==============================] - 17s 329ms/step - loss: 1.5691 - categorical_accuracy: 0.3636 - top_k_categorical_accuracy: 0.8000 - precision: 0.5511 - recall: 0.2279 - AUC: 0.8184 - true_positives: 1079.1569 - true_negatives: 50986.0781 - false_positives: 874.3922 - false_negatives: 3635.4314 - sensitivity: 0.9722 - specificity: 0.9399 - val_loss: 1.9064 - val_categorical_accuracy: 0.3743 - val_top_k_categorical_accuracy: 0.8058 - val_precision: 0.5698 - val_recall: 0.2405 - val_AUC: 0.8271 - val_true_positives: 1370.0909 - val_true_negatives: 61637.4531 - val_false_positives: 1034.5454 - val_false_negatives: 4327.3638 - val_sensitivity: 0.7500 - val_specificity: 0.7570
# Epoch 4/20
# 51/51 [==============================] - 17s 329ms/step - loss: 1.4677 - categorical_accuracy: 0.3872 - top_k_categorical_accuracy: 0.8127 - precision: 0.5871 - recall: 0.2540 - AUC: 0.8355 - true_positives: 1693.6863 - true_negatives: 72001.9219 - false_positives: 1188.1960 - false_negatives: 4959.9609 - sensitivity: 0.9870 - specificity: 0.9566 - val_loss: 3.0621 - val_categorical_accuracy: 0.3956 - val_top_k_categorical_accuracy: 0.8183 - val_precision: 0.5893 - val_recall: 0.2672 - val_AUC: 0.8411 - val_true_positives: 2041.8182 - val_true_negatives: 82632.4531 - val_false_positives: 1423.5454 - val_false_negatives: 5599.6362 - val_sensitivity: 0.8457 - val_specificity: 0.8022
# Epoch 5/20
# 51/51 [==============================] - 17s 327ms/step - loss: 1.3668 - categorical_accuracy: 0.4053 - top_k_categorical_accuracy: 0.8257 - precision: 0.5935 - recall: 0.2779 - AUC: 0.8474 - true_positives: 2394.8040 - true_negatives: 93039.8047 - false_positives: 1637.8431 - false_negatives: 6212.2549 - sensitivity: 0.9901 - specificity: 0.9657 - val_loss: 1.3947 - val_categorical_accuracy: 0.4132 - val_top_k_categorical_accuracy: 0.8327 - val_precision: 0.5990 - val_recall: 0.2864 - val_AUC: 0.8526 - val_true_positives: 2745.6365 - val_true_negatives: 103601.8203 - val_false_positives: 1838.1818 - val_false_negatives: 6839.8184 - val_sensitivity: 0.8951 - val_specificity: 0.8496
# Epoch 6/20
# 51/51 [==============================] - 17s 328ms/step - loss: 1.3107 - categorical_accuracy: 0.4223 - top_k_categorical_accuracy: 0.8391 - precision: 0.6073 - recall: 0.2963 - AUC: 0.8578 - true_positives: 3128.6863 - true_negatives: 114035.8828 - false_positives: 2020.5883 - false_negatives: 7421.9019 - sensitivity: 0.9901 - specificity: 0.9710 - val_loss: 2.1880 - val_categorical_accuracy: 0.4302 - val_top_k_categorical_accuracy: 0.8451 - val_precision: 0.6128 - val_recall: 0.3052 - val_AUC: 0.8624 - val_true_positives: 3518.4546 - val_true_negatives: 124600.5469 - val_false_positives: 2223.4546 - val_false_negatives: 8011.0000 - val_sensitivity: 0.9753 - val_specificity: 0.8973
# Epoch 7/20
# 51/51 [==============================] - 17s 328ms/step - loss: 1.2531 - categorical_accuracy: 0.4385 - top_k_categorical_accuracy: 0.8506 - precision: 0.6203 - recall: 0.3148 - AUC: 0.8671 - true_positives: 3933.1765 - true_negatives: 134962.9219 - false_positives: 2405.0784 - false_negatives: 8554.8232 - sensitivity: 0.9895 - specificity: 0.9773 - val_loss: 2.1842 - val_categorical_accuracy: 0.4438 - val_top_k_categorical_accuracy: 0.8539 - val_precision: 0.6202 - val_recall: 0.3226 - val_AUC: 0.8685 - val_true_positives: 4347.0908 - val_true_negatives: 145545.3594 - val_false_positives: 2662.6365 - val_false_negatives: 9126.3633 - val_sensitivity: 0.7377 - val_specificity: 0.8095
# Epoch 8/20
# 51/51 [==============================] - 17s 329ms/step - loss: 1.1504 - categorical_accuracy: 0.4508 - top_k_categorical_accuracy: 0.8580 - precision: 0.6224 - recall: 0.3304 - AUC: 0.8710 - true_positives: 4769.7646 - true_negatives: 155855.2188 - false_positives: 2891.6079 - false_negatives: 9661.7646 - sensitivity: 0.9926 - specificity: 0.9819 - val_loss: 2.3817 - val_categorical_accuracy: 0.4578 - val_top_k_categorical_accuracy: 0.8611 - val_precision: 0.6270 - val_recall: 0.3387 - val_AUC: 0.8739 - val_true_positives: 5222.5454 - val_true_negatives: 166485.1875 - val_false_positives: 3106.8181 - val_false_negatives: 10194.9092 - val_sensitivity: 0.8611 - val_specificity: 0.8880
# Epoch 9/20
# 51/51 [==============================] - 17s 330ms/step - loss: 1.1338 - categorical_accuracy: 0.4650 - top_k_categorical_accuracy: 0.8642 - precision: 0.6333 - recall: 0.3474 - AUC: 0.8768 - true_positives: 5691.8628 - true_negatives: 176885.9375 - false_positives: 3294.0588 - false_negatives: 10688.1377 - sensitivity: 0.9901 - specificity: 0.9855 - val_loss: 2.6681 - val_categorical_accuracy: 0.4713 - val_top_k_categorical_accuracy: 0.8672 - val_precision: 0.6385 - val_recall: 0.3546 - val_AUC: 0.8794 - val_true_positives: 6156.2729 - val_true_negatives: 187490.0000 - val_false_positives: 3486.0000 - val_false_negatives: 11205.1816 - val_sensitivity: 0.9074 - val_specificity: 0.8973
# Epoch 10/20
# 51/51 [==============================] - 17s 329ms/step - loss: 1.0641 - categorical_accuracy: 0.4790 - top_k_categorical_accuracy: 0.8709 - precision: 0.6449 - recall: 0.3630 - AUC: 0.8827 - true_positives: 6651.9019 - true_negatives: 197844.0625 - false_positives: 3660.4119 - false_negatives: 11666.6865 - sensitivity: 0.9889 - specificity: 0.9879 - val_loss: 3.1473 - val_categorical_accuracy: 0.4821 - val_top_k_categorical_accuracy: 0.8720 - val_precision: 0.6437 - val_recall: 0.3678 - val_AUC: 0.8824 - val_true_positives: 7100.1816 - val_true_negatives: 208429.9062 - val_false_positives: 3930.0908 - val_false_negatives: 12205.2725 - val_sensitivity: 0.5525 - val_specificity: 0.7649
# Epoch 11/20
# 51/51 [==============================] - 17s 329ms/step - loss: 1.0284 - categorical_accuracy: 0.4874 - top_k_categorical_accuracy: 0.8745 - precision: 0.6455 - recall: 0.3741 - AUC: 0.8837 - true_positives: 7585.3140 - true_negatives: 218822.3594 - false_positives: 4164.4707 - false_negatives: 12686.2158 - sensitivity: 0.9938 - specificity: 0.9900 - val_loss: 0.7414 - val_categorical_accuracy: 0.4925 - val_top_k_categorical_accuracy: 0.8767 - val_precision: 0.6491 - val_recall: 0.3802 - val_AUC: 0.8857 - val_true_positives: 8078.8184 - val_true_negatives: 229376.6406 - val_false_positives: 4367.3638 - val_false_negatives: 13170.6367 - val_sensitivity: 0.8642 - val_specificity: 0.8996
# Epoch 12/20
# 51/51 [==============================] - 17s 332ms/step - loss: 0.9431 - categorical_accuracy: 0.4985 - top_k_categorical_accuracy: 0.8795 - precision: 0.6547 - recall: 0.3875 - AUC: 0.8884 - true_positives: 8610.8037 - true_negatives: 239830.5469 - false_positives: 4540.2744 - false_negatives: 13604.7256 - sensitivity: 0.9938 - specificity: 0.9921 - val_loss: 1.9142 - val_categorical_accuracy: 0.5023 - val_top_k_categorical_accuracy: 0.8825 - val_precision: 0.6572 - val_recall: 0.3929 - val_AUC: 0.8906 - val_true_positives: 9111.7275 - val_true_negatives: 250374.0938 - val_false_positives: 4753.9092 - val_false_negatives: 14081.7275 - val_sensitivity: 0.9074 - val_specificity: 0.9082
# Epoch 13/20
# 51/51 [==============================] - 17s 327ms/step - loss: 0.9144 - categorical_accuracy: 0.5079 - top_k_categorical_accuracy: 0.8854 - precision: 0.6614 - recall: 0.3991 - AUC: 0.8930 - true_positives: 9643.0586 - true_negatives: 260817.1719 - false_positives: 4935.0586 - false_negatives: 14516.2354 - sensitivity: 0.9932 - specificity: 0.9917 - val_loss: 2.9954 - val_categorical_accuracy: 0.5116 - val_top_k_categorical_accuracy: 0.8875 - val_precision: 0.6615 - val_recall: 0.4034 - val_AUC: 0.8934 - val_true_positives: 10140.6367 - val_true_negatives: 271322.7188 - val_false_positives: 5189.2729 - val_false_negatives: 14996.8184 - val_sensitivity: 0.5586 - val_specificity: 0.8437
# Epoch 14/20
# 51/51 [==============================] - 17s 333ms/step - loss: 0.8753 - categorical_accuracy: 0.5163 - top_k_categorical_accuracy: 0.8896 - precision: 0.6639 - recall: 0.4093 - AUC: 0.8947 - true_positives: 10686.0391 - true_negatives: 281703.4062 - false_positives: 5406.9414 - false_negatives: 15414.9023 - sensitivity: 0.9944 - specificity: 0.9941 - val_loss: 9.6432 - val_categorical_accuracy: 0.5198 - val_top_k_categorical_accuracy: 0.8905 - val_precision: 0.6643 - val_recall: 0.4141 - val_AUC: 0.8948 - val_true_positives: 11215.6367 - val_true_negatives: 292228.5312 - val_false_positives: 5667.4546 - val_false_negatives: 15865.8184 - val_sensitivity: 0.4969 - val_specificity: 0.7769
# Epoch 15/20
# 51/51 [==============================] - 17s 329ms/step - loss: 0.8200 - categorical_accuracy: 0.5247 - top_k_categorical_accuracy: 0.8924 - precision: 0.6674 - recall: 0.4201 - AUC: 0.8958 - true_positives: 11782.0977 - true_negatives: 302598.8438 - false_positives: 5869.6274 - false_negatives: 16260.4902 - sensitivity: 0.9926 - specificity: 0.9952 - val_loss: 1.1698 - val_categorical_accuracy: 0.5292 - val_top_k_categorical_accuracy: 0.8939 - val_precision: 0.6705 - val_recall: 0.4257 - val_AUC: 0.8975 - val_true_positives: 12354.8184 - val_true_negatives: 313208.4688 - val_false_positives: 6071.5454 - val_false_negatives: 16670.6367 - val_sensitivity: 0.8148 - val_specificity: 0.9150
# Epoch 16/20
# 51/51 [==============================] - 17s 329ms/step - loss: 0.7882 - categorical_accuracy: 0.5340 - top_k_categorical_accuracy: 0.8957 - precision: 0.6746 - recall: 0.4319 - AUC: 0.8994 - true_positives: 12952.1768 - true_negatives: 323589.7188 - false_positives: 6244.6274 - false_negatives: 17032.7656 - sensitivity: 0.9944 - specificity: 0.9958 - val_loss: 1.9702 - val_categorical_accuracy: 0.5380 - val_top_k_categorical_accuracy: 0.8973 - val_precision: 0.6776 - val_recall: 0.4375 - val_AUC: 0.9008 - val_true_positives: 13550.6367 - val_true_negatives: 334215.6250 - val_false_positives: 6448.3638 - val_false_negatives: 17418.8184 - val_sensitivity: 0.7994 - val_specificity: 0.9097
# Epoch 17/20
# 51/51 [==============================] - 17s 329ms/step - loss: 0.7090 - categorical_accuracy: 0.5431 - top_k_categorical_accuracy: 0.8988 - precision: 0.6818 - recall: 0.4436 - AUC: 0.9026 - true_positives: 14163.2744 - true_negatives: 344593.6562 - false_positives: 6609.1763 - false_negatives: 17764.2559 - sensitivity: 0.9969 - specificity: 0.9967 - val_loss: 2.1990 - val_categorical_accuracy: 0.5476 - val_top_k_categorical_accuracy: 0.9005 - val_precision: 0.6852 - val_recall: 0.4488 - val_AUC: 0.9042 - val_true_positives: 14771.5459 - val_true_negatives: 355262.0000 - val_false_positives: 6786.0000 - val_false_negatives: 18141.9082 - val_sensitivity: 0.8611 - val_specificity: 0.9352
# Epoch 18/20
# 51/51 [==============================] - 17s 330ms/step - loss: 0.7046 - categorical_accuracy: 0.5528 - top_k_categorical_accuracy: 0.9024 - precision: 0.6891 - recall: 0.4547 - AUC: 0.9060 - true_positives: 15401.7256 - true_negatives: 365613.9062 - false_positives: 6947.0586 - false_negatives: 18467.4512 - sensitivity: 0.9920 - specificity: 0.9967 - val_loss: 3.0306 - val_categorical_accuracy: 0.5568 - val_top_k_categorical_accuracy: 0.9037 - val_precision: 0.6912 - val_recall: 0.4598 - val_AUC: 0.9070 - val_true_positives: 16027.5459 - val_true_negatives: 376272.2812 - val_false_positives: 7159.7271 - val_false_negatives: 18829.9082 - val_sensitivity: 0.7130 - val_specificity: 0.8707
# Epoch 19/20
# 51/51 [==============================] - 17s 329ms/step - loss: 0.6691 - categorical_accuracy: 0.5612 - top_k_categorical_accuracy: 0.9052 - precision: 0.6941 - recall: 0.4655 - AUC: 0.9084 - true_positives: 16675.8828 - true_negatives: 386714.2500 - false_positives: 7347.1763 - false_negatives: 19147.8828 - sensitivity: 0.9963 - specificity: 0.9966 - val_loss: 3.1413 - val_categorical_accuracy: 0.5641 - val_top_k_categorical_accuracy: 0.9062 - val_precision: 0.6951 - val_recall: 0.4696 - val_AUC: 0.9091 - val_true_positives: 17280.0918 - val_true_negatives: 397234.4688 - val_false_positives: 7581.5454 - val_false_negatives: 19521.3633 - val_sensitivity: 0.6821 - val_specificity: 0.8591
# Epoch 20/20
# 51/51 [==============================] - 17s 329ms/step - loss: 0.5976 - categorical_accuracy: 0.5687 - top_k_categorical_accuracy: 0.9074 - precision: 0.6982 - recall: 0.4752 - AUC: 0.9104 - true_positives: 17945.7656 - true_negatives: 407648.3125 - false_positives: 7755.6079 - false_negatives: 19818.2344 - sensitivity: 0.9963 - specificity: 0.9976 - val_loss: 0.5677 - val_categorical_accuracy: 0.5726 - val_top_k_categorical_accuracy: 0.9086 - val_precision: 0.7009 - val_recall: 0.4803 - val_AUC: 0.9117 - val_true_positives: 18608.7266 - val_true_negatives: 418259.1875 - val_false_positives: 7940.8184 - val_false_negatives: 20136.7266 - val_sensitivity: 0.8457 - val_specificity: 0.9226

# %%
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
epochs = range(len(acc))

plt.plot(acc, label='training accuracy')
plt.plot(val_acc, label='validation accuracy')
plt.title('Accuracy curve')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(loss, label='training loss')
plt.plot(val_loss, label='validation loss')
plt.title('Loss curve')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()

# %%
fig, ax = plt.subplots(6, 2, figsize=(15, 30))
ax = ax.ravel()

for i, met in enumerate(["precision", "recall", "categorical_accuracy", "loss", "AUC", "true_positives", "true_negatives",
                        "false_positives", "top_k_categorical_accuracy", "false_negatives", "sensitivity", "specificity"]):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history["val_" + met])
    ax[i].set_title("Model {}".format(met))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(met)
    ax[i].legend(["train", "val"])

# %%
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
pre = history.history['precision']
val_pre = history.history['val_precision']
rcall = history.history['recall']
val_rcall = history.history['val_recall']
aruc = history.history['AUC']
val_aruc = history.history['val_AUC']
loss = history.history['loss']
val_loss = history.history['val_loss']
true_pos = history.history['true_positives']
true_neg = history.history['true_negatives']
false_pos = history.history['false_positives']
false_neg = history.history['false_negatives']
val_true_pos = history.history['val_true_positives']
val_true_neg = history.history['val_true_negatives']
val_false_pos = history.history['val_false_positives']
val_false_neg = history.history['val_false_negatives']
sensitivity = history.history['sensitivity']
specificity = history.history['specificity']
val_sensitivity = history.history['val_sensitivity']
val_specificity = history.history['val_specificity']
top_k_categorical_accuracy = history.history['top_k_categorical_accuracy']
val_top_k_categorical_accuracy = history.history['val_top_k_categorical_accuracy']

epochs = range(1, len(acc) + 1)

# %%
#Train and validation accuracy
plt.plot(epochs, acc, 'b--', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r-v', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'b--', label='Training loss')
plt.plot(epochs, val_loss, 'r-v', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
#Train and validation accuracy on Model Precision
plt.plot(epochs, pre, 'b--', label='Training top_k_categorical_accuracy')
plt.plot(epochs, val_pre, 'r-v', label='Validation top_k_categorical_accuracy')
plt.title('Top K Categorical Accuracy')
plt.legend()

# %%
#Train and validation accuracy on Model Precision
plt.plot(epochs, pre, 'b--', label='Training precision')
plt.plot(epochs, val_pre, 'r-v', label='Validation precision')
plt.title('Model Precision')
plt.legend()

# %%
#Train and validation accuracy on Model Recall
plt.plot(epochs, rcall, 'b--', label='Training recall')
plt.plot(epochs, val_rcall, 'r-v', label='Validation recall')
plt.title('Model Recall')
plt.legend()

# %%
#Train and validation accuracy on Model AUC
plt.plot(epochs, aruc, 'b--', label='Training AUC')
plt.plot(epochs, val_aruc, 'r-v', label='Validation AUC')
plt.title('AUC')
plt.legend()

# %%
#Train and validation accuracy on True positives
plt.plot(epochs, true_pos, 'b--', label='Training True Positives')
plt.plot(epochs, val_true_pos, 'r-v', label='Validation True Positives')
plt.title('Training and Validation True Positives')
plt.legend()
plt.show()

# %%
##Train and validation accuracy on True Negatives 
plt.plot(epochs, true_neg, 'b--', label='Training True Negatives')
plt.plot(epochs, val_true_neg, 'r-v', label='Validation True Negatives')
plt.title('Training and Validation True Negatives')
plt.legend()
plt.show()

# %%
##Train and validation accuracy on False Positives
plt.plot(epochs, false_pos, 'b--', label='Training False Positives')
plt.plot(epochs, val_false_pos, 'r-v', label='Validation False Positives')
plt.title('Training and Validation False Positives')
plt.legend()
plt.show()

# %%
##Train and validation accuracy on False Negatives
plt.plot(epochs, false_neg, 'b--', label='Training False Negatives')
plt.plot(epochs, val_false_neg, 'r-v', label='Validation False Negatives')
plt.title('Training and Validation False Negatives')
plt.legend()
plt.show()

# %%
##Train and validation accuracy on specificity
plt.plot(epochs, specificity, 'b--', label='Training Specificity')
plt.plot(epochs, val_specificity, 'r-v', label='Validation Specificity')
plt.title('Training and Validation Specificity')
plt.legend()
plt.show()

# %%
##Train and validation accuracy on Sensitivity
plt.plot(epochs, sensitivity, 'b--', label='Training Sensitivity')
plt.plot(epochs, val_sensitivity, 'r-v', label='Validation Sensitivity')
plt.title('Training and Validation Sensitivity')
plt.legend()
plt.show()

# %%
metrics = model.evaluate( train_generator) 
print( 'Loss of {} and Accuracy is {} %'.format( metrics[0] , metrics[1] * 100 ) )

# %%
metrics = model.evaluate(val_generator) 
print( 'Loss of {} and Accuracy is {} %'.format( metrics[0] , metrics[1] * 100 ) )

# %%
Y_pred = model.predict_generator(val_generator, nb_validation_samples//batch_size)
y_pred = np.argmax(Y_pred, axis=1)

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
# %matplotlib inline
import itertools

#confusion Matrix and Classification Report
Y_pred = model.predict_generator(val_generator, nb_validation_samples//batch_size)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(val_generator.classes, y_pred))
print('Classification Report')
target_names = ['ATELECTASIS','BACTERIA','CARDIOMEGALY','CONSOLIDATION','COVID','EFFUSION',
                'INFILTRATION','MASS','NODULE','NORMAL','PNEUMOTHORAX','VIRUS']
print(classification_report(val_generator.classes, y_pred, target_names = target_names))

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sn
warnings.filterwarnings("ignore")
fig = plt.figure(num = None, figsize=(10, 10), dpi=40, facecolor ='w', edgecolor='k')
cm = confusion_matrix(val_generator.classes, y_pred)
conf_matrix = pd.DataFrame(data = cm, 
                           columns = ['ATELECTASIS','BACTERIA','CARDIOMEGALY','CONSOLIDATION','COVID','EFFUSION',
                                      'INFILTRATION','MASS','NODULE','NORMAL','PNEUMOTHORAX','VIRUS'], 
                           index = ['ATELECTASIS','BACTERIA','CARDIOMEGALY','CONSOLIDATION','COVID','EFFUSION',
                                    'INFILTRATION','MASS','NODULE','NORMAL','PNEUMOTHORAX','VIRUS'])
sn.set(font_scale = 1.8)# for label size
sn.heatmap(conf_matrix, annot = True,fmt='.0f', annot_kws = {"size":25}, cmap="Oranges")#font size
plt.title('Confusion Matrix', fontsize =30)
plt.show()

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sn
warnings.filterwarnings("ignore")
fig = plt.figure(num = None, figsize=(10, 10), dpi=40, facecolor ='w', edgecolor='k')
cm = confusion_matrix(val_generator.classes, y_pred)
conf_matrix = pd.DataFrame(data = cm, 
                           columns = ['ATELECTASIS','BACTERIA','CARDIOMEGALY','CONSOLIDATION','COVID','EFFUSION',
                                      'INFILTRATION','MASS','NODULE','NORMAL','PNEUMOTHORAX','VIRUS'], 
                           index = ['ATELECTASIS','BACTERIA','CARDIOMEGALY','CONSOLIDATION','COVID','EFFUSION',
                                    'INFILTRATION','MASS','NODULE','NORMAL','PNEUMOTHORAX','VIRUS'])
sn.set(font_scale = 1.8)# for label size
sn.heatmap(conf_matrix/np.sum(conf_matrix), annot = True,fmt='.2%', annot_kws = {"size":25}, cmap="Blues")#font size
plt.title('Confusion Matrix', fontsize =30)
plt.show()
#conf_matrix

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sn
warnings.filterwarnings("ignore")
fig = plt.figure(num = None, figsize=(10, 10), dpi=40, facecolor ='w', edgecolor='k')
cm = confusion_matrix(val_generator.classes, y_pred)

conf_matrix = pd.DataFrame(data = cm, 
                            columns = ['ATELECTASIS','BACTERIA','CARDIOMEGALY','CONSOLIDATION','COVID','EFFUSION',
                                       'INFILTRATION','MASS','NODULE','NORMAL','PNEUMOTHORAX','VIRUS'], 
                            index = ['ATELECTASIS','BACTERIA','CARDIOMEGALY','CONSOLIDATION','COVID','EFFUSION',
                                     'INFILTRATION','MASS','NODULE','NORMAL','PNEUMOTHORAX','VIRUS'])

labels = ['True Neg','False Pos','False Neg','True Pos']
#labels = np.asarray(labels).reshape(2,2)

sn.set(font_scale = 1.8)# for label size
sn.heatmap(conf_matrix, annot =labels, fmt='', annot_kws = {"size":25}, cmap="Oranges")#font size
plt.title('Confusion Matrix', fontsize =30)
plt.show()

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sn

from cf_matrix import make_confusion_matrix
sn.set_context('talk')

warnings.filterwarnings("ignore")
fig = plt.figure(num = None, figsize=(10, 10), dpi=40, facecolor ='w', edgecolor='k')
cm = confusion_matrix(val_generator.classes, y_pred)

conf_matrix = np.array(conf_matrix)


labels = ['True Neg','False Pos','False Neg','True Pos']
categories = ['ATELECTASIS','BACTERIA','CARDIOMEGALY','CONSOLIDATION','COVID','EFFUSION',
              'INFILTRATION','MASS','NODULE','NORMAL','PNEUMOTHORAX','VIRUS']

make_confusion_matrix(conf_matrix, group_names=labels, categories=categories, cmap='Blues', title='Confusion Matrix')

# %%
from sklearn import metrics
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score

#r = np.flip(sklearn.metrics.confusion_matrix(y_true, y_pred))
r = (confusion_matrix(val_generator.classes, y_pred))
print("Confusion Matrix")
print(r)

#precision = sklearn.metrics.precision_score(y_true=y_true, y_pred=y_pred, pos_label="positive")
precision = precision_score(y_true=val_generator.classes, y_pred=y_pred, average=None)
print('precision')
print(precision)

#recall = sklearn.metrics.recall_score(y_true=test_Y, y_pred=y_pred, pos_label="positive")
recall = recall_score(y_true=val_generator.classes, y_pred=y_pred, average=None)
print('recall')                      
print(recall)


#recall = sklearn.metrics.recall_score(y_true=test_Y, y_pred=y_pred, pos_label="positive")
#roc_auc = roc_auc_score(validation_generator.classes, y_pred, average, sample_weight)
#print('ROC AUC')                      
#print(roc_auc)

#average_precision = average_precision_score(test_Y, y_pred)
#print('Average Precision')                      
#print(average_precision)

# %%
#cm = confusion_matrix(testY.argmax(axis=1), predIdxs)
cm = confusion_matrix(val_generator.classes, y_pred)
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[0, 1] + cm[1, 1])

# show the confusion matrix, accuracy, sensitivity, and specificity
print('Confusion Matrix')
print(cm)
print("accuracy: {:.4f}".format(acc))
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))

# %%
from sklearn.metrics import classification_report
target_names = ['ATELECTASIS','BACTERIA','CARDIOMEGALY','CONSOLIDATION','COVID','EFFUSION',
                'INFILTRATION','MASS','NODULE','NORMAL','PNEUMOTHORAX','VIRUS']

print(classification_report(val_generator.classes, y_pred, target_names = target_names ))

# %%
from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model

# %%
# you will need to install numba using "pip install numba"
from numba import cuda

cuda.select_device(0)
cuda.close()
